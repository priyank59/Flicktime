# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# import requests
# import json

# api_key = "78581c2472ba1134bd2f45d55d9486b6"
# url = "https://api.themoviedb.org/3/trending/all/day"

# # Send initial request to get the total number of pages
# params = {"api_key": api_key, "page": 1}
# response = requests.get(url, params=params)

# if response.status_code == 200:
#     total_pages = json.loads(response.text)["total_pages"]
#     movies = []

#     # Send requests for each page and concatenate the results
#     for page in range(1, total_pages + 1):
#         params["page"] = page
#         response = requests.get(url, params=params)
#         page_data = json.loads(response.text)

#         if "results" in page_data:
#             movies.extend(page_data["results"])
#         else:
#             print("Error: No results found in page", page)

#     # Store the results in a file
#     with open("popular_movies.json", "w") as f:
#         json.dump(movies, f)
# else:
#     print("Error:", response.status_code, response.text)

# %%
import json
import pandas as pd

with open('popular_movies.json', 'r') as f:
    data = json.load(f)

df = pd.json_normalize(data)

# %%
df1 = df[~df.title.isnull()]

# %%
df1 = df[~df.title.isnull()]

# %%
df1[df1['backdrop_path'].isnull()]
# Out:
#        adult backdrop_path       id                               title
# 184    False          None   860407    Housewife Sex Slaves: Hatano Yui  \
# 1183   False          None   901405                            Stéphane
# 1253   False          None  1107313                   The Baby Swindler
# 1357   False          None   730629                John Wick: Chapter 5
# 1440   False          None  1107516             Louis C.K. at The Dolby
# ...      ...           ...      ...                                 ...
# 19930  False          None   130562                                Inga
# 19935  False          None   742059                           Puppeteer
# 19940  False          None   668826  Cassandra Rios: A Safo de Perdizes
# 19944  False          None   961612        The Honban Joyu Audition Hen
# 19959  False          None  1105742      Dedemit: Diikuti Makhluk Halus
#
#       original_language                      original_title
# 184                  ja                         人妻性奴隷 波多野結衣  \
# 1183                 fr                            Stéphane
# 1253                 en                   The Baby Swindler
# 1357                 en                John Wick: Chapter 5
# 1440                 en             Louis C.K. at The Dolby
# ...                 ...                                 ...
# 19930                en                     Jag - en oskuld
# 19935                ru                           Кукольник
# 19940                pt  Cassandra Rios: A Safo de Perdizes
# 19944                ja                     ザ・本番　女優オーディション篇
# 19959                id      Dedemit: Diikuti Makhluk Halus
#
#                                                 overview
# 184                                                       \
# 1183   On the set of his amateur short film, Tim unwi...
# 1253   Long before the tragic death of her husband, S...
# 1357   The fifth installment in the John Wick franchi...
# 1440   I performed and filmed this new comedy special...
# ...                                                  ...
# 19930  Inga, a 17 year-old, is sent to live with a sc...
# 19935  According to the plot, 13-year-old Sonya, her ...
# 19940  Cassandra Rios was a writer who caused controv...
# 19944                               Nikkatsu Roman Porno
# 19959  Andi Marlina Baharuddin (Fildzah Burhan) wants...
#
#                             poster_path media_type       genre_ids  ...
# 184    /7FWw1zY67W5Ckfgz9q3Z3mMdXbk.jpg      movie              []  ...  \
# 1183   /gceKQxMakhiTer6wjZTALx231PU.jpg      movie        [35, 53]  ...
# 1253                               None      movie  [53, 9648, 18]  ...
# 1357   /A1Z4TjH3xqu4rHwAgLM3LX89luC.jpg      movie    [28, 80, 53]  ...
# 1440   /2a7ma7EkRl7sqpD7TtlLt6wKBEI.jpg      movie            [35]  ...
# ...                                 ...        ...             ...  ...
# 19930  /8Bv838f1K2FWeHVYxWCbCMFZlhT.jpg      movie            [18]  ...
# 19935  /6IqanNKcxSLWPP7ieXuYBPgATaf.jpg      movie            [27]  ...
# 19940  /uRynAOge9XWqT006hIH2yGkq29o.jpg      movie            [99]  ...
# 19944  /8hwiFmedBgRjUAbSjBUobPTQKRR.jpg      movie              []  ...
# 19959                              None      movie            [27]  ...
#
#        vote_average vote_count name  original_name  first_air_date
# 184             0.0        0.0  NaN            NaN             NaN  \
# 1183            8.0        1.0  NaN            NaN             NaN
# 1253            0.0        0.0  NaN            NaN             NaN
# 1357            0.0        0.0  NaN            NaN             NaN
# 1440            0.0        0.0  NaN            NaN             NaN
# ...             ...        ...  ...            ...             ...
# 19930           4.5       10.0  NaN            NaN             NaN
# 19935           0.0        0.0  NaN            NaN             NaN
# 19940           0.0        0.0  NaN            NaN             NaN
# 19944           0.0        0.0  NaN            NaN             NaN
# 19959           0.0        0.0  NaN            NaN             NaN
#
#       origin_country gender known_for_department profile_path  known_for
# 184              NaN    NaN                  NaN          NaN        NaN
# 1183             NaN    NaN                  NaN          NaN        NaN
# 1253             NaN    NaN                  NaN          NaN        NaN
# 1357             NaN    NaN                  NaN          NaN        NaN
# 1440             NaN    NaN                  NaN          NaN        NaN
# ...              ...    ...                  ...          ...        ...
# 19930            NaN    NaN                  NaN          NaN        NaN
# 19935            NaN    NaN                  NaN          NaN        NaN
# 19940            NaN    NaN                  NaN          NaN        NaN
# 19944            NaN    NaN                  NaN          NaN        NaN
# 19959            NaN    NaN                  NaN          NaN        NaN
#
# [1127 rows x 23 columns]

# %%
df1.head()
# Out:
#    adult                     backdrop_path      id                     title
# 0  False  /bT3IpP7OopgiVuy6HCPOWLuaFAd.jpg  638974          Murder Mystery 2  \
# 1  False  /ovM06PdF3M8wvKb06i4sjW3xoww.jpg   76600  Avatar: The Way of Water
# 2  False  /4avmIRBBOs9b4DKoenf8SWWJJP7.jpg  726759                    Tetris
# 3  False  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg  677179                 Creed III
# 4  False  /tYcmm8XtzRdcT6kliCbHuWwLCwB.jpg  849869              Kill Boksoon
#
#   original_language            original_title
# 0                en          Murder Mystery 2  \
# 1                en  Avatar: The Way of Water
# 2                en                    Tetris
# 3                en                 Creed III
# 4                ko                       길복순
#
#                                             overview
# 0  After starting their own detective agency, Nic...  \
# 1  Set more than a decade after the events of the...
# 2  In 1988, American video game salesman Henk Rog...
# 3  After dominating the boxing world, Adonis Cree...
# 4  At work, she's a renowned assassin. At home, s...
#
#                         poster_path media_type       genre_ids  ...
# 0  /5wpVy0KUWzDKDKgrayM0Q8lXOiK.jpg      movie  [35, 9648, 28]  ...  \
# 1  /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg      movie   [878, 12, 28]  ...
# 2  /4F2QwCOYHJJjecSvdOjStuVLkpu.jpg      movie    [53, 36, 18]  ...
# 3  /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg      movie        [18, 28]  ...
# 4  /taYgn3RRpCGlTGdaGQvnSIOzXFy.jpg      movie    [28, 53, 12]  ...
#
#    vote_average vote_count name  original_name  first_air_date origin_country
# 0         6.700      243.0  NaN            NaN             NaN            NaN  \
# 1         7.744     6394.0  NaN            NaN             NaN            NaN
# 2         7.694      126.0  NaN            NaN             NaN            NaN
# 3         7.275      600.0  NaN            NaN             NaN            NaN
# 4         6.881       42.0  NaN            NaN             NaN            NaN
#
#   gender known_for_department profile_path  known_for
# 0    NaN                  NaN          NaN        NaN
# 1    NaN                  NaN          NaN        NaN
# 2    NaN                  NaN          NaN        NaN
# 3    NaN                  NaN          NaN        NaN
# 4    NaN                  NaN          NaN        NaN
#
# [5 rows x 23 columns]

# %%
df1.columns
# Out:
# Index(['adult', 'backdrop_path', 'id', 'title', 'original_language',
#        'original_title', 'overview', 'poster_path', 'media_type', 'genre_ids',
#        'popularity', 'release_date', 'video', 'vote_average', 'vote_count',
#        'name', 'original_name', 'first_air_date', 'origin_country', 'gender',
#        'known_for_department', 'profile_path', 'known_for'],
#       dtype='object')

# %%
df1.drop(["poster_path","original_title","media_type","backdrop_path","video","name",'original_name', 'first_air_date', 'origin_country', 'gender',
       'known_for_department', 'profile_path', 'known_for'],axis=1,inplace=True)
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/3459867679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(["poster_path","original_title","media_type","backdrop_path","video","name",'original_name', 'first_air_date', 'origin_country', 'gender',

# %%
import pandas as pd
import numpy as np

# %%
# movies = pd.read_csv('/kaggle/input/tmdb-movie-metadata/tmdb_5000_movies.csv')
# credits = pd.read_csv('/kaggle/input/tmdb-movie-metadata/tmdb_5000_credits.csv')

# %%
# movies['year'] = pd.to_datetime(movies['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
# movies.columns

# %%
# movies = movies[['id', 'title', 'overview', 'genres', 'keywords','vote_average','vote_count','year']]

# %%
# movies.isnull().sum()

# %%
# movies.dropna(inplace = True)

# %%
# df2 = movies.copy()

# %%
# df2.head()

# %%
# df2.overview[0]

# %%
import json
def genres(value):
    output_value = []
    json_data = json.loads(value)
    for item in json_data:
        output_value.append(item['name'])
    return output_value

# %%
import json
def genres_1(value):
    output_value = []
    json_data = json.loads(value)
    for item in json_data:
        output_value.append(item['id'])
    return output_value

# %%
# movies['genre_id'] = movies.genres.apply(lambda x :genres_1(x))

# %%
# movies.genres[:50]

# %%
# movies['genre_id']

# %%
# df2['keywords'][0]

# %%
# df2['genres'] = df2.genres.apply(lambda x : genres(x))

# %%
# df2['keywords'] = df2.keywords.apply(lambda x: genres(x))

# %%
# df2['keywords']

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
# features = ['keywords', 'genres']

# for feature in features:
#     df2[feature] = df2[feature].apply(clean_data)

# %%
# df2

# %%
# def create_soup(x):
#     return ' '.join(x['keywords'])  +x['overview'] + ' '.join(x['genres'])
# df2['clean'] = df2.apply(create_soup, axis=1)

# %%
# new_df = df2[['id', 'title', 'clean']]

# %%
# new_df['clean'][0]

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
# tfidf_matrix = tf.fit_transform(new_df['clean'])

# %%
# from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
# cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
# cosine_sim[0]

# %%
# new_df = new_df.reset_index()
# titles = new_df['title']
# indices = pd.Series(new_df.index, index=new_df['title'])

# %%
# def get_recommendations(title):
#     idx = indices[title] 
#     sim_scores = list(enumerate(cosine_sim[idx]))
#     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#     sim_scores = sim_scores[1:31]
#     movie_indices = [i[0] for i in sim_scores]
#     return titles.iloc[movie_indices]

# %%
# get_recommendations('The Dark Knight Rises').head(10)

# %%
vote_counts = df1[df1['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = df1[df1['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
# C

# %%
m = vote_counts.quantile(0.95)
m
# Out:
# 5622.0

# %%
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# def improved_recommendations(title):
#     idx = indices[title]
#     sim_scores = list(enumerate(cosine_sim[idx]))
#     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#     sim_scores = sim_scores[1:26]
#     movie_indices = [i[0] for i in sim_scores]
    
#     movies_1 = movies.iloc[movie_indices][['id','title', 'vote_count', 'vote_average', 'year']]
#     vote_counts = movies_1[movies_1['vote_count'].notnull()]['vote_count'].astype('int')
#     vote_averages = movies_1[movies_1['vote_average'].notnull()]['vote_average'].astype('int')
#     C = vote_averages.mean()
#     m = vote_counts.quantile(0.60)
#     qualified = movies_1[(movies_1['vote_count'] >= m) & (movies_1['vote_count'].notnull()) & (movies_1['vote_average'].notnull())]
#     qualified['vote_count'] = qualified['vote_count'].astype('int')
#     qualified['vote_average'] = qualified['vote_average'].astype('int')
#     qualified['wr'] = qualified.apply(weighted_rating, axis=1)
#     qualified = qualified.sort_values('wr', ascending=False).head(10)
#     return qualified

# %%
# improved_recommendations('The Dark Knight Rises')

# %%
# new_df.head()

# %%
df1.head()
# Out:
#    adult      id                     title original_language
# 0  False  638974          Murder Mystery 2                en  \
# 1  False   76600  Avatar: The Way of Water                en
# 2  False  726759                    Tetris                en
# 3  False  677179                 Creed III                en
# 4  False  849869              Kill Boksoon                ko
#
#                                             overview       genre_ids
# 0  After starting their own detective agency, Nic...  [35, 9648, 28]  \
# 1  Set more than a decade after the events of the...   [878, 12, 28]
# 2  In 1988, American video game salesman Henk Rog...    [53, 36, 18]
# 3  After dominating the boxing world, Adonis Cree...        [18, 28]
# 4  At work, she's a renowned assassin. At home, s...    [28, 53, 12]
#
#    popularity release_date  vote_average  vote_count
# 0     330.261   2023-03-26         6.700       243.0
# 1   10616.567   2022-12-14         7.744      6394.0
# 2      93.325   2023-03-15         7.694       126.0
# 3    2153.031   2023-03-01         7.275       600.0
# 4      47.579   2023-02-17         6.881        42.0

# %%
df1.shape
# Out:
# (13355, 10)

# %%
df.isnull().sum()
# Out:
# adult                       0
# backdrop_path            2421
# id                          0
# title                    6617
# original_language         901
# original_title           6617
# overview                  901
# poster_path              1151
# media_type                  0
# genre_ids                 902
# popularity                  1
# release_date             6618
# video                    6618
# vote_average              902
# vote_count                902
# name                    13355
# original_name           13355
# first_air_date          14256
# origin_country          14256
# gender                  19071
# known_for_department    19077
# profile_path            19304
# known_for               19071
# dtype: int64

# %%
temp = df[~df.title.isnull()]

# %%
temp.isnull().sum()
# Out:
# adult                       0
# backdrop_path            1127
# id                          0
# title                       0
# original_language           0
# original_title              0
# overview                    0
# poster_path               151
# media_type                  0
# genre_ids                   1
# popularity                  1
# release_date                1
# video                       1
# vote_average                1
# vote_count                  1
# name                    13355
# original_name           13355
# first_air_date          13355
# origin_country          13355
# gender                  13355
# known_for_department    13355
# profile_path            13355
# known_for               13355
# dtype: int64

# %%
temp.columns
# Out:
# Index(['adult', 'backdrop_path', 'id', 'title', 'original_language',
#        'original_title', 'overview', 'poster_path', 'media_type', 'genre_ids',
#        'popularity', 'release_date', 'video', 'vote_average', 'vote_count',
#        'name', 'original_name', 'first_air_date', 'origin_country', 'gender',
#        'known_for_department', 'profile_path', 'known_for'],
#       dtype='object')

# %%
temp.drop(["poster_path","original_title","media_type","backdrop_path","video","name",'original_name', 'first_air_date', 'origin_country', 'gender',
       'known_for_department', 'profile_path', 'known_for'],axis=1,inplace=True)
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/125358434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp.drop(["poster_path","original_title","media_type","backdrop_path","video","name",'original_name', 'first_air_date', 'origin_country', 'gender',

# %%
temp.isnull().sum()
# Out:
# adult                0
# id                   0
# title                0
# original_language    0
# overview             0
# genre_ids            1
# popularity           1
# release_date         1
# vote_average         1
# vote_count           1
# dtype: int64

# %%
temp.dropna(inplace = True)
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/1307770609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp.dropna(inplace = True)

# %%
temp.isnull().sum()
# Out:
# adult                0
# id                   0
# title                0
# original_language    0
# overview             0
# genre_ids            0
# popularity           0
# release_date         0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
genre_ids_temp = temp.genre_ids

# %%
genre_ids_temp
# Out:
# 0                    [35, 9648, 28]
# 1                     [878, 12, 28]
# 2                      [53, 36, 18]
# 3                          [18, 28]
# 4                      [28, 53, 12]
#                     ...
# 19965                          [35]
# 19968                 [18, 27, 878]
# 19969    [10751, 28, 12, 35, 10770]
# 19970                 [16, 28, 878]
# 19971                   [35, 10749]
# Name: genre_ids, Length: 13354, dtype: object

# %%
genre_dict = {
             28
            : "Action"
        ,
        
             12
            : "Adventure"
        ,
        
             16
            : "Animation"
        ,
        
             35
            : "Comedy"
        ,
        
             80
            : "Crime"
        ,
        
             99
            : "Documentary"
        ,
        
             18
            : "Drama"
        ,
        
             10751
            : "Family"
        ,
        
             14
            : "Fantasy"
        ,
        
             36
            : "History"
        ,
        
             27
            : "Horror"
        ,
        
             10402
            : "Music"
        ,
        
             9648
            : "Mystery"
        ,
        
             10749
            : "Romance"
        ,
        
             878
            : "Science Fiction"
        ,
             10770
            : "TV Movie"
        ,
        
             53
            : "Thriller"
        ,
        
             10752
            : "War"
        ,
        
             37
            : "Western"
        
        }

# %%
genre_dict
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
temp['genre_names'] = temp['genre_ids'].apply(lambda x: [genre_dict.get(i) for i in x])
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/3015593381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['genre_names'] = temp['genre_ids'].apply(lambda x: [genre_dict.get(i) for i in x])

# %%
temp.head()
# Out:
#    adult      id                     title original_language
# 0  False  638974          Murder Mystery 2                en  \
# 1  False   76600  Avatar: The Way of Water                en
# 2  False  726759                    Tetris                en
# 3  False  677179                 Creed III                en
# 4  False  849869              Kill Boksoon                ko
#
#                                             overview       genre_ids
# 0  After starting their own detective agency, Nic...  [35, 9648, 28]  \
# 1  Set more than a decade after the events of the...   [878, 12, 28]
# 2  In 1988, American video game salesman Henk Rog...    [53, 36, 18]
# 3  After dominating the boxing world, Adonis Cree...        [18, 28]
# 4  At work, she's a renowned assassin. At home, s...    [28, 53, 12]
#
#    popularity release_date  vote_average  vote_count
# 0     330.261   2023-03-26         6.700       243.0  \
# 1   10616.567   2022-12-14         7.744      6394.0
# 2      93.325   2023-03-15         7.694       126.0
# 3    2153.031   2023-03-01         7.275       600.0
# 4      47.579   2023-02-17         6.881        42.0
#
#                             genre_names
# 0             [Comedy, Mystery, Action]
# 1  [Science Fiction, Adventure, Action]
# 2            [Thriller, History, Drama]
# 3                       [Drama, Action]
# 4         [Action, Thriller, Adventure]

# %%
temp.info
# Out:
# <bound method DataFrame.info of        adult       id                         title original_language
# 0      False   638974              Murder Mystery 2                en  \
# 1      False    76600      Avatar: The Way of Water                en
# 2      False   726759                        Tetris                en
# 3      False   677179                     Creed III                en
# 4      False   849869                  Kill Boksoon                ko
# ...      ...      ...                           ...               ...
# 19965  False   562615           The Empire of Night                fr
# 19968  False     3105  Frankenstein: The True Story                en
# 19969  False   520720                  Kim Possible                en
# 19970  False   114478   Starship Troopers: Invasion                en
# 19971  False  1022206              Someone Borrowed                pt
#
#                                                 overview
# 0      After starting their own detective agency, Nic...  \
# 1      Set more than a decade after the events of the...
# 2      In 1988, American video game salesman Henk Rog...
# 3      After dominating the boxing world, Adonis Cree...
# 4      At work, she's a renowned assassin. At home, s...
# ...                                                  ...
# 19965  Usually cast as secret agent/private eye Lemmy...
# 19968  Victor Frankenstein witnesses his creation tur...
# 19969  Everyday teen hero Kim Possible and her best f...
# 19970  A distant Federation outpost Fort Casey comes ...
# 19971  To fulfill his mother’s dying wish and avoid b...
#
#                         genre_ids  popularity release_date  vote_average
# 0                  [35, 9648, 28]     330.261   2023-03-26         6.700  \
# 1                   [878, 12, 28]   10616.567   2022-12-14         7.744
# 2                    [53, 36, 18]      93.325   2023-03-15         7.694
# 3                        [18, 28]    2153.031   2023-03-01         7.275
# 4                    [28, 53, 12]      47.579   2023-02-17         6.881
# ...                           ...         ...          ...           ...
# 19965                        [35]       1.400   1962-12-05         0.000
# 19968               [18, 27, 878]       5.571   1974-09-19         7.500
# 19969  [10751, 28, 12, 35, 10770]      16.435   2019-02-15         5.500
# 19970               [16, 28, 878]      20.094   2012-07-21         5.900
# 19971                 [35, 10749]      26.379   2022-10-11         6.494
#
#        vote_count                                    genre_names
# 0           243.0                      [Comedy, Mystery, Action]
# 1          6394.0           [Science Fiction, Adventure, Action]
# 2           126.0                     [Thriller, History, Drama]
# 3           600.0                                [Drama, Action]
# 4            42.0                  [Action, Thriller, Adventure]
# ...           ...                                            ...
# 19965         0.0                                       [Comedy]
# 19968        24.0               [Drama, Horror, Science Fiction]
# 19969       228.0  [Family, Action, Adventure, Comedy, TV Movie]
# 19970       331.0           [Animation, Action, Science Fiction]
# 19971        89.0                              [Comedy, Romance]
#
# [13354 rows x 11 columns]>

# %%
features = ['genre_names']

for feature in features:
    temp[feature] = temp[feature].apply(clean_data)
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/780477183.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[feature] = temp[feature].apply(clean_data)

# %%
temp.head()
# Out:
#    adult      id                     title original_language
# 0  False  638974          Murder Mystery 2                en  \
# 1  False   76600  Avatar: The Way of Water                en
# 2  False  726759                    Tetris                en
# 3  False  677179                 Creed III                en
# 4  False  849869              Kill Boksoon                ko
#
#                                             overview       genre_ids
# 0  After starting their own detective agency, Nic...  [35, 9648, 28]  \
# 1  Set more than a decade after the events of the...   [878, 12, 28]
# 2  In 1988, American video game salesman Henk Rog...    [53, 36, 18]
# 3  After dominating the boxing world, Adonis Cree...        [18, 28]
# 4  At work, she's a renowned assassin. At home, s...    [28, 53, 12]
#
#    popularity release_date  vote_average  vote_count
# 0     330.261   2023-03-26         6.700       243.0  \
# 1   10616.567   2022-12-14         7.744      6394.0
# 2      93.325   2023-03-15         7.694       126.0
# 3    2153.031   2023-03-01         7.275       600.0
# 4      47.579   2023-02-17         6.881        42.0
#
#                            genre_names
# 0            [comedy, mystery, action]
# 1  [sciencefiction, adventure, action]
# 2           [thriller, history, drama]
# 3                      [drama, action]
# 4        [action, thriller, adventure]

# %%
temp['overview'] = temp['overview'].apply(lambda x: x.lower())
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/1855889817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['overview'] = temp['overview'].apply(lambda x: x.lower())

# %%
temp.head()
# Out:
#    adult      id                     title original_language
# 0  False  638974          Murder Mystery 2                en  \
# 1  False   76600  Avatar: The Way of Water                en
# 2  False  726759                    Tetris                en
# 3  False  677179                 Creed III                en
# 4  False  849869              Kill Boksoon                ko
#
#                                             overview       genre_ids
# 0  after starting their own detective agency, nic...  [35, 9648, 28]  \
# 1  set more than a decade after the events of the...   [878, 12, 28]
# 2  in 1988, american video game salesman henk rog...    [53, 36, 18]
# 3  after dominating the boxing world, adonis cree...        [18, 28]
# 4  at work, she's a renowned assassin. at home, s...    [28, 53, 12]
#
#    popularity release_date  vote_average  vote_count
# 0     330.261   2023-03-26         6.700       243.0  \
# 1   10616.567   2022-12-14         7.744      6394.0
# 2      93.325   2023-03-15         7.694       126.0
# 3    2153.031   2023-03-01         7.275       600.0
# 4      47.579   2023-02-17         6.881        42.0
#
#                            genre_names
# 0            [comedy, mystery, action]
# 1  [sciencefiction, adventure, action]
# 2           [thriller, history, drama]
# 3                      [drama, action]
# 4        [action, thriller, adventure]

# %%
def create_soup(x):
    return  x['overview'] + ' '.join(x['genre_names'])
temp['clean'] = temp.apply(create_soup, axis=1)
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/1144338914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['clean'] = temp.apply(create_soup, axis=1)

# %%
train_1 = temp[['clean','id','title']]

# %%
train_1.head()
# Out:
#                                                clean      id
# 0  after starting their own detective agency, nic...  638974  \
# 1  set more than a decade after the events of the...   76600
# 2  in 1988, american video game salesman henk rog...  726759
# 3  after dominating the boxing world, adonis cree...  677179
# 4  at work, she's a renowned assassin. at home, s...  849869
#
#                       title
# 0          Murder Mystery 2
# 1  Avatar: The Way of Water
# 2                    Tetris
# 3                 Creed III
# 4              Kill Boksoon

# %%
# %pip install -U scikit-learn scipy matplotlib
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp311-cp311-macosx_12_0_arm64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 13.0 MB/s eta 0:00:0000:0100:01
# Collecting scipy
#   Downloading scipy-1.10.1-cp311-cp311-macosx_12_0_arm64.whl (28.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.7/28.7 MB 20.9 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp311-cp311-macosx_11_0_arm64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 19.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.24.2)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 18.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp311-cp311-macosx_11_0_arm64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 14.0 MB/s eta 0:00:0000:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/spartan/Library/Python/3.11/lib/python/site-packages (from matplotlib) (23.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp311-cp311-macosx_11_0_arm64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/spartan/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: threadpoolctl, scipy, pillow, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.3 joblib-1.2.0 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 scikit-learn-1.2.2 scipy-1.10.1 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(train_1['clean'])

# %%
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
cosine_sim[0]
# Out:
# array([1.        , 0.00236701, 0.        , ..., 0.00409421, 0.00138278,
#        0.00278872])

# %%
train_1 = train_1.reset_index()
titles = train_1['title']
indices = pd.Series(train_1.index, index=train_1['title'])

# %%
def get_recommendations(title):
    idx = indices[title] 
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations('Avatar: The Way of Water').head(10)
# Out:
# 8285                Nobody's Fool
# 4657                  Night Teeth
# 2277                   Safe House
# 9506     SPY x FAMILY CODE: White
# 171                   Terrifier 2
# 3734          Monster of The Deep
# 4493            Geocentric Crisis
# 6801                        Alien
# 5181                        Alive
# 10425              To Save a Life
# Name: title, dtype: object

# %%
def improved_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    
    movies_1 = temp.iloc[movie_indices][['id','title', 'vote_count', 'vote_average']]
    vote_counts = movies_1[movies_1['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = movies_1[movies_1['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_averages.mean()
    m = vote_counts.quantile(0.60)
    qualified = movies_1[(movies_1['vote_count'] >= m) & (movies_1['vote_count'].notnull()) & (movies_1['vote_average'].notnull())]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    qualified['wr'] = qualified.apply(weighted_rating, axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(10)
    return qualified

# %%
improved_recommendations('Avatar: The Way of Water')
# Out:
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/4201599636.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified['vote_count'] = qualified['vote_count'].astype('int')
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/4201599636.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified['vote_average'] = qualified['vote_average'].astype('int')
# /var/folders/xx/ftp2gqxj7m38q0p19pgl3m840000gr/T/ipykernel_21227/4201599636.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified['wr'] = qualified.apply(weighted_rating, axis=1)
#            id                                    title  vote_count
# 619    119450           Dawn of the Planet of the Apes       10027  \
# 6286   550776  Believe Me: The Abduction of Lisa McVey         467
# 3273    59961                               Safe House        3169
# 5378     8456                          Never Back Down        2071
# 7554     7305                                    Alive        1243
# 271    663712                              Terrifier 2        1118
# 6780   669671                              Night Teeth         644
# 12211   11593                            Nobody's Fool         246
# 13979   13613                          Day of the Dead         320
# 11102   10069                               Stay Alive         632
#
#        vote_average        wr
# 619               7  6.463107
# 6286              8  5.696856
# 3273              6  5.683785
# 5378              6  5.638653
# 7554              6  5.595070
# 271               6  5.587560
# 6780              6  5.556360
# 12211             6  5.526270
# 13979             5  5.478316
# 11102             5  5.454454

# %%
temp.head()
# Out:
#    adult      id                     title original_language
# 0  False  638974          Murder Mystery 2                en  \
# 1  False   76600  Avatar: The Way of Water                en
# 2  False  726759                    Tetris                en
# 3  False  677179                 Creed III                en
# 4  False  849869              Kill Boksoon                ko
#
#                                             overview       genre_ids
# 0  after starting their own detective agency, nic...  [35, 9648, 28]  \
# 1  set more than a decade after the events of the...   [878, 12, 28]
# 2  in 1988, american video game salesman henk rog...    [53, 36, 18]
# 3  after dominating the boxing world, adonis cree...        [18, 28]
# 4  at work, she's a renowned assassin. at home, s...    [28, 53, 12]
#
#    popularity release_date  vote_average  vote_count
# 0     330.261   2023-03-26         6.700       243.0  \
# 1   10616.567   2022-12-14         7.744      6394.0
# 2      93.325   2023-03-15         7.694       126.0
# 3    2153.031   2023-03-01         7.275       600.0
# 4      47.579   2023-02-17         6.881        42.0
#
#                            genre_names
# 0            [comedy, mystery, action]  \
# 1  [sciencefiction, adventure, action]
# 2           [thriller, history, drama]
# 3                      [drama, action]
# 4        [action, thriller, adventure]
#
#                                                clean
# 0  after starting their own detective agency, nic...
# 1  set more than a decade after the events of the...
# 2  in 1988, american video game salesman henk rog...
# 3  after dominating the boxing world, adonis cree...
# 4  at work, she's a renowned assassin. at home, s...

# %%
temp1 = temp[['title','clean']]

# %%
temp.head()
# Out:
#    adult      id                     title original_language
# 0  False  638974          Murder Mystery 2                en  \
# 1  False   76600  Avatar: The Way of Water                en
# 2  False  726759                    Tetris                en
# 3  False  677179                 Creed III                en
# 4  False  849869              Kill Boksoon                ko
#
#                                             overview       genre_ids
# 0  after starting their own detective agency, nic...  [35, 9648, 28]  \
# 1  set more than a decade after the events of the...   [878, 12, 28]
# 2  in 1988, american video game salesman henk rog...    [53, 36, 18]
# 3  after dominating the boxing world, adonis cree...        [18, 28]
# 4  at work, she's a renowned assassin. at home, s...    [28, 53, 12]
#
#    popularity release_date  vote_average  vote_count
# 0     330.261   2023-03-26         6.700       243.0  \
# 1   10616.567   2022-12-14         7.744      6394.0
# 2      93.325   2023-03-15         7.694       126.0
# 3    2153.031   2023-03-01         7.275       600.0
# 4      47.579   2023-02-17         6.881        42.0
#
#                            genre_names
# 0            [comedy, mystery, action]  \
# 1  [sciencefiction, adventure, action]
# 2           [thriller, history, drama]
# 3                      [drama, action]
# 4        [action, thriller, adventure]
#
#                                                clean
# 0  after starting their own detective agency, nic...
# 1  set more than a decade after the events of the...
# 2  in 1988, american video game salesman henk rog...
# 3  after dominating the boxing world, adonis cree...
# 4  at work, she's a renowned assassin. at home, s...

# %%
# pickle.dump(temp.to_dict(), open('movie_df.pkl', 'wb'))

# %%
temp1
# Out:
#                               title
# 0                  Murder Mystery 2  \
# 1          Avatar: The Way of Water
# 2                            Tetris
# 3                         Creed III
# 4                      Kill Boksoon
# ...                             ...
# 19965           The Empire of Night
# 19968  Frankenstein: The True Story
# 19969                  Kim Possible
# 19970   Starship Troopers: Invasion
# 19971              Someone Borrowed
#
#                                                    clean
# 0      after starting their own detective agency, nic...
# 1      set more than a decade after the events of the...
# 2      in 1988, american video game salesman henk rog...
# 3      after dominating the boxing world, adonis cree...
# 4      at work, she's a renowned assassin. at home, s...
# ...                                                  ...
# 19965  usually cast as secret agent/private eye lemmy...
# 19968  victor frankenstein witnesses his creation tur...
# 19969  everyday teen hero kim possible and her best f...
# 19970  a distant federation outpost fort casey comes ...
# 19971  to fulfill his mother’s dying wish and avoid b...
#
# [13354 rows x 2 columns]

# %%
import pickle
pickle.dump(temp.to_dict(), open('movie_df.pkl', 'wb'))

# %%
import pickle
pickle.dump(cosine_sim, open('cosine_sim.pkl', 'wb'))
